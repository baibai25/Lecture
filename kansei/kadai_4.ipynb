# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x_df = pd.read_csv('kadai4.csv', index_col=0)
y_df = pd.read_csv('kadai3.csv', header=None, index_col=0)
y = pd.DataFrame(y_df[y_df.columns[2]])
y = y.rename(columns={y.columns[0]: 'Label'})

# %%
pd.concat([x_df, y], axis=1)
# Out:
#           単色  2色  多色  支配–暖色  支配–中間色  支配–冷色  注目–暖色  注目–中間色  注目–冷色  Label
# Sample1    0   0   1      0       1      0      0       0      1      1
# Sample2    1   0   0      1       0      0      1       0      0      2
# Sample3    0   1   0      1       0      0      1       0      0      2
# Sample4    1   0   0      1       0      0      1       0      0      2
# Sample5    0   1   0      1       0      0      0       0      1      2
# Sample6    1   0   0      0       0      1      0       0      1     -1
# Sample7    0   0   1      0       1      0      0       1      0     -2
# Sample8    0   0   1      1       0      1      1       0      1     -1
# Sample9    0   0   1      0       0      1      0       0      1     -2
# Sample10   0   0   1      1       0      0      1       0      0      2
# Sample11   0   1   0      0       0      1      0       0      1     -2
# Sample12   0   0   1      0       0      1      0       0      1     -1

# %%
x = np.array(x_df)
y = np.array(y)

# %%
clf = LinearRegression(normalize=True)
clf.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
# 回帰係数, 切片 (誤差), 決定係数
coef = clf.coef_
intercept = clf.intercept_
score = clf.score(x, y)
print(coef, intercept, score)
# Out:
# [[ 0.2        -0.22424242  0.01818182  1.01233263 -0.23009161 -2.7149401
#   -0.52748414 -3.25475687 -0.25475687]] [1.46666667] 0.9779099405267629

# %%
pd.DataFrame(coef.T, index=x_df.columns, columns=['coef'])
# Out:
#             coef
# 単色      0.200000
# 2色     -0.224242
# 多色      0.018182
# 支配–暖色   1.012333
# 支配–中間色 -0.230092
# 支配–冷色  -2.714940
# 注目–暖色  -0.527484
# 注目–中間色 -3.254757
# 注目–冷色  -0.254757
